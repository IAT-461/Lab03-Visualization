# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set_theme(style="whitegrid", palette="muted")

# %%
df = pd.read_csv("data/music_streams.csv")

# %%
df.head()
# Out:
#    track_id     title                        artist    genre  year duration  \
# 0  TRK00001  Memories                 Juno Calloway      R&B  2024     3:15
# 1  TRK00002     Tears                     Cleo Nova    Indie  2020     2:40
# 2  TRK00003      Soul  Cole Voss ft. Indigo Ashford     Rock  2017     3:55
# 3  TRK00004     Heart                  Asha Ashford     Rock  2022     3:05
# 4  TRK00005     Bones                   Theo Blaine  Hip-Hop  2015     3:09
#
#    duration_sec  tempo_bpm       key  energy  ...  valence  acousticness  \
# 0           195         85   F Minor   0.502  ...    0.872         0.694
# 1           160         68  F# Major   0.610  ...    0.545         0.485
# 2           235        140   D Major   0.742  ...    0.483         0.281
# 3           185         73   A Major   0.643  ...    0.634         0.505
# 4           189        143  G# Major   0.770  ...    0.223         0.394
#
#    speechiness  loudness_db  explicit  streams_millions  monthly_listeners  \
# 0        0.148         -8.8     False              3.73                176
# 1        0.111         -3.9     False              3.10                170
# 2        0.050         -4.1      True             18.22                770
# 3        0.092         -8.6     False              0.23                  1
# 4        0.105        -13.4     False              0.72                  1
#
#    playlist_adds  chart_peak        label
# 0           8336         NaN         AWAL
# 1           1625         NaN   A24 Sounds
# 2          42971         NaN  Dead Oceans
# 3            484         NaN   Sony Music
# 4           1101         NaN   A24 Sounds
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['track_id', 'title', 'artist', 'genre', 'year', 'duration',
#        'duration_sec', 'tempo_bpm', 'key', 'energy', 'danceability', 'valence',
#        'acousticness', 'speechiness', 'loudness_db', 'explicit',
#        'streams_millions', 'monthly_listeners', 'playlist_adds', 'chart_peak',
#        'label'],
#       dtype='object')

# %%
len(df["label"].unique())
# Out:
# 13

# %%
df.describe()
# Out:
#               year  duration_sec   tempo_bpm       energy  danceability  \
# count  1200.000000   1200.000000  1200.00000  1200.000000   1200.000000
# mean   2020.416667    208.478333   111.85000     0.630888      0.420776
# std       2.572983     38.430439    24.02079     0.197475      0.185624
# min    2015.000000     90.000000    60.00000     0.062000      0.000000
# 25%    2018.000000    183.000000    89.00000     0.487000      0.291000
# 50%    2021.000000    208.000000   117.00000     0.641500      0.426000
# 75%    2023.000000    234.000000   131.00000     0.773250      0.545000
# max    2024.000000    325.000000   165.00000     1.000000      1.000000
#
#            valence  acousticness  speechiness  loudness_db  streams_millions  \
# count  1200.000000   1200.000000  1200.000000  1200.000000       1200.000000
# mean      0.490212      0.492011     0.162236    -7.632583         10.171200
# std       0.190506      0.199972     0.175026     3.440571         23.480756
# min       0.023000      0.000000     0.006000   -20.000000          0.050000
# 25%       0.352000      0.354750     0.057000    -9.900000          1.740000
# 50%       0.498500      0.486500     0.101000    -7.600000          4.060000
# 75%       0.623250      0.630000     0.190500    -5.300000         10.330000
# max       0.969000      1.000000     1.000000    -1.000000        523.170000
#
#        monthly_listeners  playlist_adds  chart_peak
# count        1200.000000    1200.000000  398.000000
# mean          547.436667   18006.349167   35.271357
# std          1167.522745   41026.124735   42.904225
# min             1.000000      50.000000    1.000000
# 25%            95.750000    2483.750000    9.000000
# 50%           223.000000    6641.500000   19.000000
# 75%           555.250000   17412.750000   43.000000
# max         16655.000000  646358.000000  200.000000

# %% [markdown]
# ## Histogram

# %% [markdown]
# ### Monthly streams

# %%
fig, ax= plt.subplots(figsize=(9,4))
median = df.streams_millions.median()
mean = df.streams_millions.mean()
sns.histplot(data=df[df.streams_millions <100], x="streams_millions",bins=20,ax=ax,color="steelblue")
ax.axvline(median, color="darkorange", linestyle="--", label=f"median: {median:.2f}")
ax.axvline(mean, color="darkred", label=f"mean: {mean:.2f}")
ax.legend(frameon=False)
ax.set_xlabel('Monthly Streams (millions)')
ax.set_ylabel('Song count')
ax.set_title("Monthly Streams")
plt.show()

# %% [markdown]
# ## Boxplots

# %%
order = df.groupby("genre")["energy"].median().sort_values(ascending=False).index
order
# Out:
# Index(['Electronic', 'Rock', 'Latin', 'Hip-Hop', 'Pop', 'Country', 'Indie',
#        'R&B'],
#       dtype='object', name='genre')

# %%
fig, ax = plt.subplots(figsize=(10,4))
sns.boxplot(data=df, y="energy",x="genre",order=order,ax=ax)
# Out:
# <Axes: xlabel='genre', ylabel='energy'>

# %%
df["monthy_listeners_log"] = np.log(df["monthly_listeners"])
df["monthy_listeners_log"]
# Out:
# 0       5.170484
# 1       5.135798
# 2       6.646391
# 3       0.000000
# 4       0.000000
#           ...
# 1195    6.100319
# 1196    7.375882
# 1197    5.192957
# 1198    5.733341
# 1199    6.066108
# Name: monthy_listeners_log, Length: 1200, dtype: float64

# %%
order = df.groupby("genre")["monthly_listeners"].median().sort_values(ascending=False).index
order
fig, ax = plt.subplots(figsize=(10,4))
ax.set_yscale('log', base=2)
sns.boxplot(data=df, y="monthly_listeners",x="genre",order=order,ax=ax)
# Out:
# <Axes: xlabel='genre', ylabel='monthly_listeners'>

# %% [markdown]
# ## Scatterplot

# %%
sample = df.sample(600)
fig, ax = plt.subplots(figsize=(8,5))
sns.scatterplot(data=df, x="energy", y="danceability",hue="genre",color="grey",alpha=0.5,palette="tab10")
sns.regplot(data=df, x="energy", y="danceability",scatter=False,color="black")
# Out:
# <Axes: xlabel='energy', ylabel='danceability'>

# %%
g= sns.FacetGrid(df,col="genre", col_wrap=4)
g.map(sns.scatterplot, "energy", "danceability")

# %% [markdown]
# ## Line Charts and Friends

# %%
df.head()
# Out:
#    track_id     title                        artist    genre  year duration  \
# 0  TRK00001  Memories                 Juno Calloway      R&B  2024     3:15
# 1  TRK00002     Tears                     Cleo Nova    Indie  2020     2:40
# 2  TRK00003      Soul  Cole Voss ft. Indigo Ashford     Rock  2017     3:55
# 3  TRK00004     Heart                  Asha Ashford     Rock  2022     3:05
# 4  TRK00005     Bones                   Theo Blaine  Hip-Hop  2015     3:09
#
#    duration_sec  tempo_bpm       key  energy  ...  acousticness  speechiness  \
# 0           195         85   F Minor   0.502  ...         0.694        0.148
# 1           160         68  F# Major   0.610  ...         0.485        0.111
# 2           235        140   D Major   0.742  ...         0.281        0.050
# 3           185         73   A Major   0.643  ...         0.505        0.092
# 4           189        143  G# Major   0.770  ...         0.394        0.105
#
#    loudness_db  explicit  streams_millions  monthly_listeners  playlist_adds  \
# 0         -8.8     False              3.73                176           8336
# 1         -3.9     False              3.10                170           1625
# 2         -4.1      True             18.22                770          42971
# 3         -8.6     False              0.23                  1            484
# 4        -13.4     False              0.72                  1           1101
#
#    chart_peak        label  monthy_listeners_log
# 0         NaN         AWAL              5.170484
# 1         NaN   A24 Sounds              5.135798
# 2         NaN  Dead Oceans              6.646391
# 3         NaN   Sony Music              0.000000
# 4         NaN   A24 Sounds              0.000000
#
# [5 rows x 22 columns]

# %%
df.year.unique()
# Out:
# array([2024, 2020, 2017, 2022, 2015, 2023, 2021, 2019, 2018, 2016])

# %%
pop_trend = df[df["genre"] == "Pop"].groupby("year")["streams_millions"].median()
pop_trend
# Out:
# year
# 2015     7.160
# 2016     3.540
# 2017     3.560
# 2018    11.370
# 2019     4.720
# 2020     5.075
# 2021     3.645
# 2022     4.445
# 2023     4.230
# 2024     3.390
# Name: streams_millions, dtype: float64

# %%
df.genre.unique()
# Out:
# array(['R&B', 'Indie', 'Rock', 'Hip-Hop', 'Pop', 'Electronic', 'Latin',
#        'Country'], dtype=object)

# %%
[i for i in zip(axes,genres)]
# Out:
# [(<Axes: >, 'Pop'),
#  (<Axes: >, 'Hip-Hop'),
#  (<Axes: >, 'Rock'),
#  (<Axes: >, 'Electronic'),
#  (<Axes: >, 'R&B'),
#  (<Axes: >, 'Indie')]

# %%
genres = ["Pop", "Hip-Hop", "Rock", "Electronic", "R&B","Indie"]

trend = df[df.genre.isin(genres)].groupby(["year","genre"])["streams_millions"].median().reset_index()

fig, axes = plt.subplots(2,3,figsize=(12,5),sharex=True,sharey=True)
axes = axes.flatten()

for ax, genre in zip(axes, genres):
    subD = trend[trend.genre == genre]
    ax.plot(subD.year, subD.streams_millions,marker="o", ms=5)
    peak = subD.loc[subD.streams_millions.idxmax()]
    ax.annotate(f"peak: {peak.streams_millions:.1f} M",xy=(peak.year,peak.streams_millions), 
                xytext=(20,20), textcoords="offset points",ha="center",fontsize=8, arrowprops=dict(arrowstyle="->",color="black",lw=1))
    ax.set_title(genre, fontweight="bold")
